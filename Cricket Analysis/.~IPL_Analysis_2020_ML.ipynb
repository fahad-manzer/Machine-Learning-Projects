# %%
import numpy as np 
import pandas as pd 
import os 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
match_result_df=pd.read_csv('/content/IPLMatchResults2020.csv')

# %%
match_result_df
# Out:
#     Match No        TEAMS  TOSS CHOOSE_TO        GROUND First_half_score  \
# 0          1    CSK vs MI   CSK      BOWL  Sheikh Zayed            162/9
# 1          2   DC vs KXIP  KXIP      BOWL         Dubai            157/8
# 2          3   RCB vs SRH   SRH      BOWL         Dubai            163/5
# 3          4    RR vs CSK   CSK      BOWL       Sharjah            216/7
# 4          5    MI vs KKR   KKR      BOWL  Sheikh Zayed            195/5
# 5          6  KXIP vs RCB   RCB      BOWL         Dubai            206/3
# 6          7    DC vs CSK   CSK      BOWL         Dubai            175/3
# 7          8   SRH vs KKR   SRH       BAT  Sheikh Zayed            142/4
# 8          9   KXIP vs RR    RR      BOWL       Sharjah            223/2
# 9         10    MI vs RCB    MI      BOWL         Dubai            201/3
# 10        11    SRH vs DC    DC      BOWL  Sheikh Zayed            162/4
# 11        12    KKR vs RR    RR      BOWL         Dubai            174/6
# 12        13   MI vs KXIP  KXIP      BOWL  Sheikh Zayed            191/4
# 13        14   CSK vs SRH   SRH       BAT         Dubai            164/5
# 14        15    RCB vs RR    RR       BAT  Sheikh Zayed            154/6
# 15        16    DC vs KKR   KKR      BOWL       Sharjah            228/4
# 16        17    MI vs SRH    MI       BAT       Sharjah            208/5
# 17        18  KXIP vs CSK  KXIP       BAT         Dubai            178/4
# 18        19    DC vs RCB   RCB      BOWL         Dubai            196/4
# 19        20      MI v RR    MI       BAT  Sheikh Zayed            193/4
# 20        21   KKR vs CSK   KKR       BAT  Sheikh Zayed           167/10
# 21        22  SRH vs KXIP   SRH       BAT         Dubai            201/6
# 22        23    RR  vs DC    RR      BOWL       Sharjah            184/8
# 23        24  KKR vs KXIP   KKR       BAT  Sheikh Zayed            164/6
# 24        25   CSK vs RCB   RCB       BAT         Dubai            169/4
# 25        26    SRH vs RR   SRH       BAT         Dubai            158/4
# 26        27     MI vs DC    DC       BAT  Sheikh Zayed            162/4
# 27        28   RCB vs KKR   RCB       BAT       Sharjah            194/2
# 28        29   CSK vs SRH   CSK       BAT         Dubai            167/6
# 29        30     DC vs RR    DC       BAT         Dubai            161/7
# 30        31  RCB vs KXIP   RCB       BAT       Sharjah            171/6
# 31        32    KKR vs MI   KKR       BAT  Sheikh Zayed            148/5
# 32        33    RR vs RCB    RR       BAT         Dubai            177/6
# 33        34    CSK vs DC   CSK       BAT       Sharjah            179/4
# 34        35   SRH vs KKR   SRH      BOWL  Sheikh Zayed            163/5
# 35        36   MI vs KXIP    MI       BAT         Dubai            176/6
# 36        37    RR vs CSK   CSK       BAT  Sheikh Zayed            125/5
# 37        38   KXIP vs DC    DC       BAT         Dubai            164/5
# 38        39   KKR vs RCB   KKR       BAT  Sheikh Zayed             84/8
# 39        40    SRH vs RR   SRH      BOWL         Dubai            154/6
# 40        41    CSK vs MI    MI      BOWL       Sharjah            114/9
# 41        42    KKR vs DC    DC      BOWL  Sheikh Zayed            194/6
# 42        43  KXIP vs SRH   SRH      BOWL         Dubai            126/7
# 43        44   CSK vs RCB   RCB       BAT         Dubai            145/6
# 44        45     MI vs RR    MI       BAT  Sheikh Zayed            195/5
# 45        46  KKR vs KXIP  KXIP      BOWL       Sharjah            149/9
# 46        47    SRH vs DC    DC      BOWL         Dubai            219/2
# 47        48    MI vs RCB    MI      BOWL  Sheikh Zayed            164/6
# 48        49   CSK vs KKR   CSK      BOWL         Dubai            172/5
# 49        50   KXIP vs RR    RR      BOWL  Sheikh Zayed            185/4
# 50        51     MI vs DC    MI      BOWL         Dubai            110/9
# 51        52   RCB vs SRH   SRH      BOWL       Sharjah            120/7
# 52        53  CSK vs KXIP   CSK      BOWL  Sheikh Zayed            153/6
# 53        54    KKR vs RR    RR      BOWL         Dubai            191/7
# 54        55    RCB vs DC    DC      BOWL  Sheikh Zayed            152/7
# 55        56    SRH vs MI   SRH      BOWL       Sharjah            149/8
# 56        57     MI vs DC    DC      BOWL         Dubai            200/5
# 57        58   SRH vs RCB   SRH      BOWL  Sheikh Zayed            131/7
# 58        59    SRH vs DC    DC       BAT  Sheikh Zayed            189/3
# 59        60     MI vs DC    DC       BAT         Dubai            156/7
#
#    Second_half_score RESULT (won_by)  Super_over                 MOM
# 0              166/5             CSK           0       Ambati Rayudu
# 1              157/8              DC           1      Marcus Stoinis
# 2             153/10             RCB           0            Y Chahal
# 3              200/6              RR           0        Sanju Samson
# 4              146/9              MI           0        Rohit Sharma
# 5             109/10            KXIP           0            KL Rahul
# 6              131/7              DC           0        Prithvi Shaw
# 7              145/3             KKR           0        Shubman Gill
# 8              226/6              RR           0        Sanju Samson
# 9              201/5             RCB           1      AB de Villiers
# 10             147/7             SRH           0         Rashid Khan
# 11             137/9             KKR           0         Shivam Mavi
# 12             143/8              MI           0        Rohit Sharma
# 13             157/5             SRH           0         Priyam Garg
# 14             158/2             RCB           0            Y Chahal
# 15             210/8              DC           0        Shreyas Iyer
# 16             174/7              MI           0               Boult
# 17             181/0             CSK           0              Watson
# 18             137/9              DC           0          Axar Patel
# 19            136/10              MI           0    Suryakumar Yadav
# 20             157/5             KKR           0      Rahul Tripathi
# 21            132/10             SRH           0            Bairstow
# 22            138/10              DC           0              Ashwin
# 23             162/5             KKR           0      Dinesh Karthik
# 24             132/8             RCB           0         Virat Kohli
# 25             163/5              RR           0       Rahul Tewatia
# 26             166/5              MI           0             de Kock
# 27             112/9             RCB           0      AB de Villiers
# 28             147/8             CSK           0     Ravindra Jadeja
# 29             148/8              DC           0       Anrich Nortje
# 30             177/2            KXIP           0            KL Rahul
# 31             149/2              MI           0             de Kock
# 32             179/3             RCB           0      AB de Villiers
# 33             185/5              DC           0      Shikhar Dhawan
# 34             163/6             KKR           1     Lockie Ferguson
# 35             176/6            KXIP           1            KL Rahul
# 36             126/3              RR           0          Jos Butler
# 37             167/5            KXIP           0      Shikhar Dhawan
# 38              85/2             RCB           0      Mohammed Siraj
# 39             156/2             SRH           0       Manish Pandey
# 40             116/0              MI           0               Boult
# 41             135/9             KKR           0  Varun Chakravarthy
# 42            114/10            KXIP           0        Chris Jordan
# 43             150/2             CSK           0     Ruturaj Gaikwad
# 44             196/2              RR           0          Ben Stokes
# 45             150/2            KXIP           0         Chris Gayle
# 46            131/10             SRH           0              W Saha
# 47             166/5              MI           0    Suryakumar Yadav
# 48             178/4             CSK           0     Ruturaj Gaikwad
# 49             186/3              RR           0          Ben Stokes
# 50             111/1              MI           0        Ishan Kishan
# 51             121/5             SRH           0      Sandeep Sharma
# 52             154/1             CSK           0     Ruturaj Gaikwad
# 53             131/9             KKR           0         Pat Cummins
# 54             154/4              DC           0       Anrich Nortje
# 55             151/0             SRH           0      Shahbaz Nadeem
# 56             143/8              MI           0      Jasprit Bumrah
# 57             132/4             SRH           0     Kane Williamson
# 58             172/8              DC           0      Marcus Stoinis
# 59             157/5              MI           0               Boult

# %%
match_result_df.loc[22,'TEAMS']='RR vs DC'

# %%
match_result_df.loc[19,'TEAMS']='MI vs RR'

# %%
match_result_df.head()
# Out:
#    Match No       TEAMS  TOSS CHOOSE_TO        GROUND First_half_score  \
# 0         1   CSK vs MI   CSK      BOWL  Sheikh Zayed            162/9
# 1         2  DC vs KXIP  KXIP      BOWL         Dubai            157/8
# 2         3  RCB vs SRH   SRH      BOWL         Dubai            163/5
# 3         4   RR vs CSK   CSK      BOWL       Sharjah            216/7
# 4         5   MI vs KKR   KKR      BOWL  Sheikh Zayed            195/5
#
#   Second_half_score RESULT (won_by)  Super_over             MOM
# 0             166/5             CSK           0   Ambati Rayudu
# 1             157/8              DC           1  Marcus Stoinis
# 2            153/10             RCB           0        Y Chahal
# 3             200/6              RR           0    Sanju Samson
# 4             146/9              MI           0    Rohit Sharma

# %%
match_result_df.sum()
# Out:
# Match No                                                          1830
# TEAMS                CSK vs MIDC vs KXIPRCB vs SRHRR vs CSKMI vs KK...
# TOSS                 CSKKXIPSRHCSKKKRRCBCSKSRHRRMIDCRRKXIPSRHRRKKRM...
# CHOOSE_TO            BOWLBOWLBOWLBOWLBOWLBOWLBOWLBATBOWLBOWLBOWLBOW...
# GROUND               Sheikh ZayedDubaiDubaiSharjahSheikh ZayedDubai...
# First_half_score     162/9157/8163/5216/7195/5206/3175/3142/4223/22...
# Second_half_score    166/5157/8153/10200/6146/9109/10131/7145/3226/...
# RESULT (won_by)      CSKDCRCBRRMIKXIPDCKKRRRRCBSRHKKRMISRHRCBDCMICS...
# Super_over                                                           4
# MOM                  Ambati RayuduMarcus StoinisY ChahalSanju Samso...
# dtype: object

# %%
match_result_df.isna().sum()
# Out:
# Match No             0
# TEAMS                0
# TOSS                 0
# CHOOSE_TO            0
# GROUND               0
# First_half_score     0
# Second_half_score    0
# RESULT (won_by)      0
# Super_over           0
# MOM                  0
# dtype: int64

# %%
match_result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Match No           60 non-null     int64
#  1   TEAMS              60 non-null     object
#  2   TOSS               60 non-null     object
#  3   CHOOSE_TO          60 non-null     object
#  4   GROUND             60 non-null     object
#  5   First_half_score   60 non-null     object
#  6   Second_half_score  60 non-null     object
#  7   RESULT (won_by)    60 non-null     object
#  8   Super_over         60 non-null     int64
#  9   MOM                60 non-null     object
# dtypes: int64(2), object(8)
# memory usage: 4.8+ KB

# %% [markdown]
# The Toss

# %%
plt.figure(figsize=(8,5),)
match_result_df['TOSS'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# The Luckiest team with the Toss is SRH.SRH won 11 out of 16 toss.
#
# The unlukiest team with the toss is KXIP.KXIP only won 4 out of 14 tosses.
#
# Does winning the toss means winning the match?

# %%
won=0
lost=0
for i in range (60):
  if match_result_df.iloc[i,-3]==match_result_df.iloc[i,2]:
    won+=1
  else:
    lost+=1

# %%
print(f"Out of 60 matches.in {won} matches the team that won the toss the won the match.\n")
print(f"That is in {round((won/60)*100)}% of the matches,team that won the toss won the match.")
# Out:
# Out of 60 matches.in 25 matches the team that won the toss the won the match.
#
# That is in 42% of the matches,team that won the toss won the match.

# %%
toss_vs_result=pd.DataFrame({"Won_match":[25,35],'Lost_match':[35,25]},index=["Won_toss",'Lost_toss'])
toss_vs_result
# Out:
#            Won_match  Lost_match
# Won_toss          25          35
# Lost_toss         35          25

# %%
from scipy.stats import chi2_contingency

# %% [markdown]
# Null Hypothesis:There is No significant relation between winning the toss and winning the match.
#
# Alternate Hypothesis: There is significant relation between winning the toss and winning the match.

# %%
chi2_contingency(toss_vs_result)
# Out:
# Chi2ContingencyResult(statistic=2.7, pvalue=0.10034824646229054, dof=1, expected_freq=array([[30., 30.],
#        [30., 30.]]))

# %%
team_wise_toss_vs_result=pd.crosstab(match_result_df['TOSS'],match_result_df['RESULT (won_by)'])
team_wise_toss_vs_result
# Out:
# RESULT (won_by)  CSK  DC  KKR  KXIP  MI  RCB  RR  SRH
# TOSS
# CSK                4   2    0     0   0    0   2    0
# DC                 0   3    1     1   3    0   0    2
# KKR                0   1    2     0   2    1   0    0
# KXIP               1   1    0     1   1    0   0    0
# MI                 0   0    0     1   5    1   1    0
# RCB                1   1    0     2   0    2   0    0
# RR                 0   1    2     0   0    2   2    0
# SRH                0   0    2     1   0    1   1    6

# %%
for team in team_wise_toss_vs_result.index:
  toss_won=team_wise_toss_vs_result.loc[team,:].sum()
  match_won=team_wise_toss_vs_result.loc[team,team]
  print(f"In {round((match_won/toss_won)*100,2)} % of the matches of {team},{team} won the Toss and won the MATCH\n")
# Out:
# In 50.0 % of the matches of CSK,CSK won the Toss and won the MATCH
#
# In 30.0 % of the matches of DC,DC won the Toss and won the MATCH
#
# In 33.33 % of the matches of KKR,KKR won the Toss and won the MATCH
#
# In 25.0 % of the matches of KXIP,KXIP won the Toss and won the MATCH
#
# In 62.5 % of the matches of MI,MI won the Toss and won the MATCH
#
# In 33.33 % of the matches of RCB,RCB won the Toss and won the MATCH
#
# In 28.57 % of the matches of RR,RR won the Toss and won the MATCH
#
# In 54.55 % of the matches of SRH,SRH won the Toss and won the MATCH

# %% [markdown]
# Chase or Defend

# %%
chase=0
defend=0
for i in range (60):
  if match_result_df.iloc[i,-3]==match_result_df.iloc[i,2]:
    if match_result_df.iloc[i,3]=='BOWL':
      chase+=1
    else:
      defend+=1
  else:
    if match_result_df.iloc[i,3]=='BOWL':
      defend+=1
    else:
      chase+=1

# %%
print(f"{chase} out of 60 times team chasing won the match and \n{defend} out of 60 times team defending won the match.")
# Out:
# 30 out of 60 times team chasing won the match and
# 30 out of 60 times team defending won the match.

# %% [markdown]
# That is,chasing and defending had exactly equal probability in winning a match in IPL 2020

# %%
for team in match_result_df['RESULT (won_by)'].unique():
  bowl_first=0
  bat_first=0
  temp_df=match_result_df[match_result_df['RESULT (won_by)']==team]
  for i in range(temp_df.shape[0]):
    if temp_df.iloc[i,2]==team:
      if temp_df.iloc[i,3]=='BOWL':
        bowl_first+=1
      else:
        bat_first+=1
    else:
      if temp_df.iloc[i,3]=='BOWL':
        bat_first+=1
      else:
        bowl_first+=1
  print(f"Out of {temp_df.shape[0]} wins by {team}:")
  print(f"{bowl_first} matche(s) were won by bowling first and \n{bat_first} matche(s) were won by batting first.\n\n")
# Out:
# Out of 6 wins by CSK:
# 5 matche(s) were won by bowling first and
# 1 matche(s) were won by batting first.
#
#
# Out of 9 wins by DC:
# 2 matche(s) were won by bowling first and
# 7 matche(s) were won by batting first.
#
#
# Out of 7 wins by RCB:
# 3 matche(s) were won by bowling first and
# 4 matche(s) were won by batting first.
#
#
# Out of 6 wins by RR:
# 5 matche(s) were won by bowling first and
# 1 matche(s) were won by batting first.
#
#
# Out of 11 wins by MI:
# 6 matche(s) were won by bowling first and
# 5 matche(s) were won by batting first.
#
#
# Out of 6 wins by KXIP:
# 4 matche(s) were won by bowling first and
# 2 matche(s) were won by batting first.
#
#
# Out of 7 wins by KKR:
# 1 matche(s) were won by bowling first and
# 6 matche(s) were won by batting first.
#
#
# Out of 8 wins by SRH:
# 4 matche(s) were won by bowling first and
# 4 matche(s) were won by batting first.

# %% [markdown]
# Stadium

# %%
stadiums=match_result_df['GROUND'].unique()
print(f"{len(stadiums)} used in IPL 2020 were: ")
i=0
for stadium in stadiums:
  i+=1
  print(f"{i}.{stadium}")
# Out:
# 3 used in IPL 2020 were:
# 1.Sheikh Zayed
# 2.Dubai
# 3.Sharjah

# %%
for stadium in stadiums:
  temp_stadium_df=match_result_df[match_result_df['GROUND']==stadium]
  chase=0
  defend=0
  for i in range(temp_stadium_df.shape[0]):
    if temp_stadium_df.iloc[i,3]=='BOWL':
      chase+=1
    else:
      defend+=1
  else:
      if match_result_df.iloc[i,3]=='BOWL':
        defend+=1
      else:
        chase+=1
  print("\n stadium: ",stadium)
  print("-----------------------------")
  print(f"Total no matches played in {stadium} stadium: { temp_stadium_df.shape[0]}")
  print(f"Number of wins by chasing a total: {chase}")
  print(f"Number of wins by defending a total: {defend}")
  print(f"Win percentage of chasing a total:{round((chase/temp_stadium_df.shape[0])*100,2)} %")
  print(f"Win percentage of chasing a total:{round((defend/temp_stadium_df.shape[0])*100,2)} %")
  print("******************************")
# Out:
#  stadium:  Sheikh Zayed
# -----------------------------
# Total no matches played in Sheikh Zayed stadium: 22
# Number of wins by chasing a total: 12
# Number of wins by defending a total: 11
# Win percentage of chasing a total:54.55 %
# Win percentage of chasing a total:50.0 %
# ******************************
#
#  stadium:  Dubai
# -----------------------------
# Total no matches played in Dubai stadium: 26
# Number of wins by chasing a total: 15
# Number of wins by defending a total: 12
# Win percentage of chasing a total:57.69 %
# Win percentage of chasing a total:46.15 %
# ******************************
#
#  stadium:  Sharjah
# -----------------------------
# Total no matches played in Sharjah stadium: 12
# Number of wins by chasing a total: 8
# Number of wins by defending a total: 5
# Win percentage of chasing a total:66.67 %
# Win percentage of chasing a total:41.67 %
# ******************************

# %% [markdown]
# In IPL 2020,teams performed better by defending a total in Sheikh Zayed statdium and teams performed better by chasing a total in Sharajah Statdium.
#
# In Dubai statdium.teams performed equally well bu chasing and defending a total.
#
# Checking statstically wheather batting or bollowing first had a significant effect on the result in each stadium,

# %%
#Sheikh Zayed Statdium 
#total number of matches played in Sheikh Zayed Statdium:22
#Number of Wins by chasing a total:64
#Number of wins by defending a total:16
Sheikh_Zayed=pd.DataFrame({"Won":[6,16],"Lost":[16,6]},index=['Cahsing','Defending'])
Sheikh_Zayed
# Out:
#            Won  Lost
# Cahsing      6    16
# Defending   16     6

# %% [markdown]
# As pvalue=0.006 is less than 0.05,we reject Null Hypothesis.
#
# Hence, We can say that there is statistical proof that team  defending a total have a better chance of winning in Sheikh Zayed Statdium.

# %%
#Sharjah Statdium 
#total number of matches played in Sharajah Statdium:12
#Number of Wins by chasing a total:8
#Number of wins by defending a total:4
Sharjah=pd.DataFrame({"Won":[8,4],"Lost":[4,8]},index=['Cahsing','Defending'])
Sharjah
# Out:
#            Won  Lost
# Cahsing      8     4
# Defending    4     8

# %%
chi2_contingency(Sharjah)
# Out:
# Chi2ContingencyResult(statistic=1.5, pvalue=0.22067136191984324, dof=1, expected_freq=array([[6., 6.],
#        [6., 6.]]))

# %% [markdown]
# As the pvalue=0.22 is greater than 0.05.we accept Null Hypothesis.
#
# Hence,we can say that in Sharjah Stadium,we do not have any statistical proof to say that chasing a total has a better chancr of winning.
#
# First innings and second innings in each statdium.

# %%
for stadium in stadiums:
    fi_runs = 0
    fi_wick = 0
    si_runs = 0
    si_wick = 0
    temp_stadium_df = match_result_df[match_result_df['GROUND'] == stadium]
    fi_runs = temp_stadium_df.loc[:,'First_half_score'].apply(lambda x:int(x.split('/')[0]))
    fi_wick = temp_stadium_df.loc[:,'First_half_score'].apply(lambda x:int(x.split('/')[1]))
    si_runs = temp_stadium_df.loc[:,'Second_half_score'].apply(lambda x:int(x.split('/')[0]))
    si_wick = temp_stadium_df.loc[:,'Second_half_score'].apply(lambda x:int(x.split('/')[1]))
    print("\nStadium: ",stadium)
    print("---------------------")
    print(f"Total number of matches played in {stadium} stadium: {temp_stadium_df.shape[0]}")
    print(f"Total Runs scored in {stadium} stadium: {np.sum(fi_runs) + np.sum(si_runs)}")
    print(f"Total Wickets taken in {stadium} stadium: {np.sum(fi_wick)+np.sum(si_wick)}")
    print(f"Average first innings score: {round(np.mean(fi_runs))}")
    print(f"Average wickets taken in first innings: {round(np.mean(fi_wick))}")
    print(f"Average second innings score: {round(np.mean(si_runs))}")
    print(f"Average wickets taken in first second: {round(np.mean(si_wick))}")
    print("***********************")
# Out:
# Stadium:  Sheikh Zayed
# ---------------------
# Total number of matches played in Sheikh Zayed stadium: 22
# Total Runs scored in Sheikh Zayed stadium: 6919
# Total Wickets taken in Sheikh Zayed stadium: 231
# Average first innings score: 162
# Average wickets taken in first innings: 6
# Average second innings score: 152
# Average wickets taken in first second: 5
# ***********************
#
# Stadium:  Dubai
# ---------------------
# Total number of matches played in Dubai stadium: 26
# Total Runs scored in Dubai stadium: 8338
# Total Wickets taken in Dubai stadium: 306
# Average first innings score: 172
# Average wickets taken in first innings: 5
# Average second innings score: 149
# Average wickets taken in first second: 6
# ***********************
#
# Stadium:  Sharjah
# ---------------------
# Total number of matches played in Sharjah stadium: 12
# Total Runs scored in Sharjah stadium: 4095
# Total Wickets taken in Sharjah stadium: 131
# Average first innings score: 178
# Average wickets taken in first innings: 6
# Average second innings score: 163
# Average wickets taken in first second: 5
# ***********************

# %%
print("\nStadium: ",stadium)
print("-----------")
print(f"Total number of matches played in {stadium} stadium:{temp_stadium_df.shape[0]}")
print(f'Total Runs scored in {stadium} stadium:{np.sum(fi_runs)+np.sum(si_runs)}')
print(f"Total Wickets taken in {stadium} stadium:{np.sum(fi_wick)+np.sum(si_wick)}")
print(f"Average first innnings score: {np.mean(fi_runs)}")
print(f"Average wickets taken in first innings:{np.mean(fi_wick)}") 
print(f"Average second innnings score:{np.mean(si_runs)}")
print(f"Average wickets taken in first second:{np.mean(si_wick)}")
print("******************")
# Out:
# Stadium:  Sharjah
# -----------
# Total number of matches played in Sharjah stadium:12
# Total Runs scored in Sharjah stadium:4095
# Total Wickets taken in Sharjah stadium:131
# Average first innnings score: 177.91666666666666
# Average wickets taken in first innings:5.916666666666667
# Average second innnings score:163.33333333333334
# Average wickets taken in first second:5.0
# ******************

# %%
match_detailed = match_result_df.copy()

# %%
match_detailed['First_Inns_Runs'] = match_detailed['First_half_score'].apply(lambda x:int(x.split('/')[0]))
match_detailed['First_Inns_Wkts'] = match_detailed['First_half_score'].apply(lambda x:int(x.split('/')[1]))
match_detailed['Second_Inns_Runs'] = match_detailed['Second_half_score'].apply(lambda x:int(x.split('/')[0]))
match_detailed['Second_Inns_Wkts'] = match_detailed['Second_half_score'].apply(lambda x:int(x.split('/')[1]))

# %%
team_batting_first = []
team_batting_second = []
for i in range(match_detailed.shape[0]):
    if match_detailed.loc[i,'CHOOSE_TO'] == 'BOWL':
        team1 = set()
        team1.add(match_detailed.loc[i,'TOSS'])
        teams_playing = set(match_detailed.loc[i,'TEAMS'].split(' vs '))
        team2 = teams_playing - team1
        team_batting_first.append(list(team2)[0])
        team_batting_second.append(list(team1)[0])
    else:
        team1 = set()
        team1.add(match_detailed.loc[i,'TOSS'])
        teams_playing = set(match_detailed.loc[i,'TEAMS'].split(' vs '))
        team2 = teams_playing - team1
        team_batting_first.append(list(team1)[0])
        team_batting_second.append(list(team2)[0])

# %%
match_detailed['Team_Batting_First'] = team_batting_first
match_detailed['Team_Batting_Second'] = team_batting_second

# %%
match_detailed = match_detailed[['Team_Batting_First','Team_Batting_Second','TOSS', 'CHOOSE_TO', 'GROUND','First_Inns_Runs', 'First_Inns_Wkts', 'Second_Inns_Runs',
       'Second_Inns_Wkts','RESULT (won_by)', 'Super_over', 'MOM']]

# %%
match_detailed
# Out:
#    Team_Batting_First Team_Batting_Second  TOSS CHOOSE_TO        GROUND  \
# 0                  MI                 CSK   CSK      BOWL  Sheikh Zayed
# 1                  DC                KXIP  KXIP      BOWL         Dubai
# 2                 RCB                 SRH   SRH      BOWL         Dubai
# 3                  RR                 CSK   CSK      BOWL       Sharjah
# 4                  MI                 KKR   KKR      BOWL  Sheikh Zayed
# 5                KXIP                 RCB   RCB      BOWL         Dubai
# 6                  DC                 CSK   CSK      BOWL         Dubai
# 7                 SRH                 KKR   SRH       BAT  Sheikh Zayed
# 8                KXIP                  RR    RR      BOWL       Sharjah
# 9                 RCB                  MI    MI      BOWL         Dubai
# 10                SRH                  DC    DC      BOWL  Sheikh Zayed
# 11                KKR                  RR    RR      BOWL         Dubai
# 12                 MI                KXIP  KXIP      BOWL  Sheikh Zayed
# 13                SRH                 CSK   SRH       BAT         Dubai
# 14                 RR                 RCB    RR       BAT  Sheikh Zayed
# 15                 DC                 KKR   KKR      BOWL       Sharjah
# 16                 MI                 SRH    MI       BAT       Sharjah
# 17               KXIP                 CSK  KXIP       BAT         Dubai
# 18                 DC                 RCB   RCB      BOWL         Dubai
# 19                 MI                  RR    MI       BAT  Sheikh Zayed
# 20                KKR                 CSK   KKR       BAT  Sheikh Zayed
# 21                SRH                KXIP   SRH       BAT         Dubai
# 22                 DC                  RR    RR      BOWL       Sharjah
# 23                KKR                KXIP   KKR       BAT  Sheikh Zayed
# 24                RCB                 CSK   RCB       BAT         Dubai
# 25                SRH                  RR   SRH       BAT         Dubai
# 26                 DC                  MI    DC       BAT  Sheikh Zayed
# 27                RCB                 KKR   RCB       BAT       Sharjah
# 28                CSK                 SRH   CSK       BAT         Dubai
# 29                 DC                  RR    DC       BAT         Dubai
# 30                RCB                KXIP   RCB       BAT       Sharjah
# 31                KKR                  MI   KKR       BAT  Sheikh Zayed
# 32                 RR                 RCB    RR       BAT         Dubai
# 33                CSK                  DC   CSK       BAT       Sharjah
# 34                KKR                 SRH   SRH      BOWL  Sheikh Zayed
# 35                 MI                KXIP    MI       BAT         Dubai
# 36                CSK                  RR   CSK       BAT  Sheikh Zayed
# 37                 DC                KXIP    DC       BAT         Dubai
# 38                KKR                 RCB   KKR       BAT  Sheikh Zayed
# 39                 RR                 SRH   SRH      BOWL         Dubai
# 40                CSK                  MI    MI      BOWL       Sharjah
# 41                KKR                  DC    DC      BOWL  Sheikh Zayed
# 42               KXIP                 SRH   SRH      BOWL         Dubai
# 43                RCB                 CSK   RCB       BAT         Dubai
# 44                 MI                  RR    MI       BAT  Sheikh Zayed
# 45                KKR                KXIP  KXIP      BOWL       Sharjah
# 46                SRH                  DC    DC      BOWL         Dubai
# 47                RCB                  MI    MI      BOWL  Sheikh Zayed
# 48                KKR                 CSK   CSK      BOWL         Dubai
# 49               KXIP                  RR    RR      BOWL  Sheikh Zayed
# 50                 DC                  MI    MI      BOWL         Dubai
# 51                RCB                 SRH   SRH      BOWL       Sharjah
# 52               KXIP                 CSK   CSK      BOWL  Sheikh Zayed
# 53                KKR                  RR    RR      BOWL         Dubai
# 54                RCB                  DC    DC      BOWL  Sheikh Zayed
# 55                 MI                 SRH   SRH      BOWL       Sharjah
# 56                 MI                  DC    DC      BOWL         Dubai
# 57                RCB                 SRH   SRH      BOWL  Sheikh Zayed
# 58                 DC                 SRH    DC       BAT  Sheikh Zayed
# 59                 DC                  MI    DC       BAT         Dubai
#
#     First_Inns_Runs  First_Inns_Wkts  Second_Inns_Runs  Second_Inns_Wkts  \
# 0               162                9               166                 5
# 1               157                8               157                 8
# 2               163                5               153                10
# 3               216                7               200                 6
# 4               195                5               146                 9
# 5               206                3               109                10
# 6               175                3               131                 7
# 7               142                4               145                 3
# 8               223                2               226                 6
# 9               201                3               201                 5
# 10              162                4               147                 7
# 11              174                6               137                 9
# 12              191                4               143                 8
# 13              164                5               157                 5
# 14              154                6               158                 2
# 15              228                4               210                 8
# 16              208                5               174                 7
# 17              178                4               181                 0
# 18              196                4               137                 9
# 19              193                4               136                10
# 20              167               10               157                 5
# 21              201                6               132                10
# 22              184                8               138                10
# 23              164                6               162                 5
# 24              169                4               132                 8
# 25              158                4               163                 5
# 26              162                4               166                 5
# 27              194                2               112                 9
# 28              167                6               147                 8
# 29              161                7               148                 8
# 30              171                6               177                 2
# 31              148                5               149                 2
# 32              177                6               179                 3
# 33              179                4               185                 5
# 34              163                5               163                 6
# 35              176                6               176                 6
# 36              125                5               126                 3
# 37              164                5               167                 5
# 38               84                8                85                 2
# 39              154                6               156                 2
# 40              114                9               116                 0
# 41              194                6               135                 9
# 42              126                7               114                10
# 43              145                6               150                 2
# 44              195                5               196                 2
# 45              149                9               150                 2
# 46              219                2               131                10
# 47              164                6               166                 5
# 48              172                5               178                 4
# 49              185                4               186                 3
# 50              110                9               111                 1
# 51              120                7               121                 5
# 52              153                6               154                 1
# 53              191                7               131                 9
# 54              152                7               154                 4
# 55              149                8               151                 0
# 56              200                5               143                 8
# 57              131                7               132                 4
# 58              189                3               172                 8
# 59              156                7               157                 5
#
#    RESULT (won_by)  Super_over                 MOM
# 0              CSK           0       Ambati Rayudu
# 1               DC           1      Marcus Stoinis
# 2              RCB           0            Y Chahal
# 3               RR           0        Sanju Samson
# 4               MI           0        Rohit Sharma
# 5             KXIP           0            KL Rahul
# 6               DC           0        Prithvi Shaw
# 7              KKR           0        Shubman Gill
# 8               RR           0        Sanju Samson
# 9              RCB           1      AB de Villiers
# 10             SRH           0         Rashid Khan
# 11             KKR           0         Shivam Mavi
# 12              MI           0        Rohit Sharma
# 13             SRH           0         Priyam Garg
# 14             RCB           0            Y Chahal
# 15              DC           0        Shreyas Iyer
# 16              MI           0               Boult
# 17             CSK           0              Watson
# 18              DC           0          Axar Patel
# 19              MI           0    Suryakumar Yadav
# 20             KKR           0      Rahul Tripathi
# 21             SRH           0            Bairstow
# 22              DC           0              Ashwin
# 23             KKR           0      Dinesh Karthik
# 24             RCB           0         Virat Kohli
# 25              RR           0       Rahul Tewatia
# 26              MI           0             de Kock
# 27             RCB           0      AB de Villiers
# 28             CSK           0     Ravindra Jadeja
# 29              DC           0       Anrich Nortje
# 30            KXIP           0            KL Rahul
# 31              MI           0             de Kock
# 32             RCB           0      AB de Villiers
# 33              DC           0      Shikhar Dhawan
# 34             KKR           1     Lockie Ferguson
# 35            KXIP           1            KL Rahul
# 36              RR           0          Jos Butler
# 37            KXIP           0      Shikhar Dhawan
# 38             RCB           0      Mohammed Siraj
# 39             SRH           0       Manish Pandey
# 40              MI           0               Boult
# 41             KKR           0  Varun Chakravarthy
# 42            KXIP           0        Chris Jordan
# 43             CSK           0     Ruturaj Gaikwad
# 44              RR           0          Ben Stokes
# 45            KXIP           0         Chris Gayle
# 46             SRH           0              W Saha
# 47              MI           0    Suryakumar Yadav
# 48             CSK           0     Ruturaj Gaikwad
# 49              RR           0          Ben Stokes
# 50              MI           0        Ishan Kishan
# 51             SRH           0      Sandeep Sharma
# 52             CSK           0     Ruturaj Gaikwad
# 53             KKR           0         Pat Cummins
# 54              DC           0       Anrich Nortje
# 55             SRH           0      Shahbaz Nadeem
# 56              MI           0      Jasprit Bumrah
# 57             SRH           0     Kane Williamson
# 58              DC           0      Marcus Stoinis
# 59              MI           0               Boult

# %%
match_detailed.groupby('GROUND')[['First_Inns_Runs', 'Second_Inns_Runs']].mean().plot(kind='bar',figsize=(8,7))
plt.show()

# %%
match_detailed.groupby('GROUND')[['First_Inns_Wkts','Second_Inns_Wkts']].mean().plot(kind='bar',figsize=(8,7))
plt.show()

# %% [markdown]
# Teams
#
# Statistics of each team batting first

# %%
bat_first_df = match_detailed.groupby('Team_Batting_First').agg({'First_Inns_Runs':[np.mean,np.sum],'First_Inns_Wkts':[np.mean,np.sum]})

# %%
bat_first_df.columns = ['Average runs scored','Total runs scored',
            'Average wicket fall','Total Wicket Fall']

# %%
temp_df = pd.DataFrame(match_detailed.groupby('Team_Batting_First')['Team_Batting_First'].count())
temp_df.columns = ['No. of Matches']

# %%
bat_first_df = pd.concat([temp_df,bat_first_df],axis=1)

# %%
bat_first_df.sort_values('Average runs scored',ascending=False)
# Out:
#                     No. of Matches  Average runs scored  Total runs scored  \
# Team_Batting_First
# MI                               9           185.444444               1669
# KXIP                             6           178.500000               1071
# RR                               4           175.250000                701
# SRH                              6           174.333333               1046
# DC                              11           171.090909               1882
# RCB                             10           161.000000               1610
# KKR                             10           160.600000               1606
# CSK                              4           146.250000                585
#
#                     Average wicket fall  Total Wicket Fall
# Team_Batting_First
# MI                             5.666667                 51
# KXIP                           4.333333                 26
# RR                             6.250000                 25
# SRH                            4.166667                 25
# DC                             5.636364                 62
# RCB                            5.300000                 53
# KKR                            6.700000                 67
# CSK                            6.000000                 24

# %%
colors = ['yellow','deepskyblue','indigo','indianred','blue','red','violet','orangered']

# %%
plt.figure(figsize=(8,6))
plt.title("Average First Innings Score of each Team")
sns.barplot(y=bat_first_df.sort_index()['Average runs scored'],x=bat_first_df.sort_index().index,palette=colors)
plt.xlabel('Team')
plt.show()

# %% [markdown]
# Mumbai Indians has the highest first innings average.
#
# Statistics of each team batting second

# %%
bat_second_df = match_detailed.groupby('Team_Batting_Second').agg({'Second_Inns_Runs':[np.mean,np.sum],'Second_Inns_Wkts':[np.mean,np.sum]})

# %%
bat_second_df.columns = ['Average runs scored','Total runs scored',
            'Average wicket fall','Total Wicket Fall']

# %%
temp_df = pd.DataFrame(match_detailed.groupby('Team_Batting_Second')['Team_Batting_Second'].count())
temp_df.columns = ['No. of Matches']

# %%
bat_second_df = pd.concat([temp_df,bat_second_df],axis=1)

# %%
bat_second_df.sort_values('Average runs scored',ascending=False)
# Out:
#                      No. of Matches  Average runs scored  Total runs scored  \
# Team_Batting_Second
# CSK                              10           160.600000               1606
# RR                               10           158.700000               1587
# KXIP                              8           158.000000               1264
# KKR                               4           153.250000                613
# MI                                7           152.285714               1066
# DC                                6           149.166667                895
# SRH                              10           148.300000               1483
# RCB                               5           133.600000                668
#
#                      Average wicket fall  Total Wicket Fall
# Team_Batting_Second
# CSK                             4.300000                 43
# RR                              6.500000                 65
# KXIP                            5.750000                 46
# KKR                             7.250000                 29
# MI                              3.285714                 23
# DC                              7.166667                 43
# SRH                             6.000000                 60
# RCB                             5.200000                 26

# %%
plt.figure(figsize=(8,6))
plt.title("Average Second Innings Score of each Team")
sns.barplot(y=bat_second_df.sort_index()['Average runs scored'],x=bat_second_df.sort_index().index,palette=colors)
plt.xlabel('Team')
plt.show()

# %% [markdown]
# Chennai Super Kings has the highest second innings score average.
#
# Statistics of each team fielding first

# %%
field_first_df = match_detailed.groupby('Team_Batting_Second').agg({'First_Inns_Runs':[np.mean,np.sum],'First_Inns_Wkts':[np.mean,np.sum]})

# %%
field_first_df.columns = ['Average runs conceded','Total runs conceded',
            'Average wickets taken','Total wickets taken']

# %%
temp_df = pd.DataFrame(match_detailed.groupby('Team_Batting_Second')['Team_Batting_Second'].count())
temp_df.columns = ['No. of Matches']

# %%
field_first_df = pd.concat([temp_df,field_first_df],axis=1)

# %%
field_first_df.index.name='Team Fielding First'

# %%
field_first_df.sort_values('Average runs conceded')
# Out:
#                      No. of Matches  Average runs conceded  \
# Team Fielding First
# MI                                7             150.714286
# SRH                              10             157.000000
# RCB                               5             163.400000
# CSK                              10             170.100000
# KXIP                              8             171.625000
# RR                               10             178.900000
# DC                                6             184.333333
# KKR                               4             189.750000
#
#                      Total runs conceded  Average wickets taken  \
# Team Fielding First
# MI                                  1055               6.142857
# SRH                                 1570               5.900000
# RCB                                  817               5.400000
# CSK                                 1701               5.900000
# KXIP                                1373               6.250000
# RR                                  1789               5.200000
# DC                                  1106               4.666667
# KKR                                  759               3.750000
#
#                      Total wickets taken
# Team Fielding First
# MI                                    43
# SRH                                   59
# RCB                                   27
# CSK                                   59
# KXIP                                  50
# RR                                    52
# DC                                    28
# KKR                                   15

# %%
plt.figure(figsize=(8,6))
plt.title("Average Runs Conceded in First Innings")
sns.barplot(y=field_first_df.sort_index()['Average runs conceded'],x=field_first_df.sort_index().index,palette=colors)
plt.xlabel('Team')
plt.show()

# %% [markdown]
# Mumbai Indians has the lowest first innings runs conceded.
#
# Statistics of each team fielding second

# %%
field_second_df = match_detailed.groupby('Team_Batting_First').agg({'Second_Inns_Runs':[np.mean,np.sum],'Second_Inns_Wkts':[np.mean,np.sum]})

# %%
field_second_df.columns = ['Average runs conceded','Total runs conceded',
            'Average wickets taken','Total wickets taken']

# %%
temp_df = pd.DataFrame(match_detailed.groupby('Team_Batting_First')['Team_Batting_First'].count())
temp_df.columns = ['No. of Matches']

# %%
field_second_df = pd.concat([temp_df,field_second_df],axis=1)

# %%
field_second_df.index.name = 'Team Fielding Second'

# %%
field_second_df.sort_values('Average runs conceded')
# Out:
#                       No. of Matches  Average runs conceded  \
# Team Fielding Second
# CSK                                4             143.500000
# KKR                               10             144.700000
# SRH                                6             145.833333
# RCB                               10             149.800000
# DC                                11             154.000000
# MI                                 9             159.000000
# KXIP                               6             161.666667
# RR                                 4             173.250000
#
#                       Total runs conceded  Average wickets taken  \
# Team Fielding Second
# CSK                                   574               4.000000
# KKR                                  1447               5.300000
# SRH                                   875               6.666667
# RCB                                  1498               5.400000
# DC                                   1694               6.727273
# MI                                   1431               6.111111
# KXIP                                  970               5.000000
# RR                                    693               3.250000
#
#                       Total wickets taken
# Team Fielding Second
# CSK                                    16
# KKR                                    53
# SRH                                    40
# RCB                                    54
# DC                                     74
# MI                                     55
# KXIP                                   30
# RR                                     13

# %%
plt.figure(figsize=(8,6))
plt.title("Average Runs Conceded in Second Innings")
sns.barplot(y=field_second_df.sort_index()['Average runs conceded'],x=field_second_df.sort_index().index,palette=colors)
plt.xlabel('Team')
plt.show()

# %% [markdown]
# CSK has the lowest first innings runs conceded.
#
# Difference between runs scored by a team in the first innings and the runs conceded by the team in the second innings

# %%
diff_scored_conceded = pd.DataFrame(bat_first_df.sort_index()['Average runs scored'] - field_second_df.sort_index()['Average runs conceded'])

# %%
diff_scored_conceded.index.name = 'Team'
diff_scored_conceded.columns = ['Runs_scored - Runs_conceded']
diff_scored_conceded.sort_values('Runs_scored - Runs_conceded',ascending=False)
# Out:
#       Runs_scored - Runs_conceded
# Team
# SRH                     28.500000
# MI                      26.444444
# DC                      17.090909
# KXIP                    16.833333
# KKR                     15.900000
# RCB                     11.200000
# CSK                      2.750000
# RR                       2.000000

# %%
plt.figure(figsize=(8,6))
plt.title("Difference between Runs Scored in 1st innings and Runs Conceded in 2nd innings")
sns.barplot(y=diff_scored_conceded.sort_index()['Runs_scored - Runs_conceded'],x=diff_scored_conceded.sort_index().index,palette=colors)
plt.xlabel('Team')
plt.show()

# %% [markdown]
# When SRH was batting first, the team chasing the target scored around 29 runs lesser than the target on an average
#
#
# Difference between runs conceded by a team in the first innings and the runs scored by the team in the second innings

# %%
diff_conceded_scored = pd.DataFrame(bat_second_df.sort_index()['Average runs scored']-field_first_df.sort_index()['Average runs conceded'])

# %%
diff_conceded_scored.index.name = 'Team'
diff_conceded_scored.columns = ['Runs_conceded-Runs_scored']
diff_conceded_scored.sort_values('Runs_conceded-Runs_scored',ascending=False)
# Out:
#       Runs_conceded-Runs_scored
# Team
# MI                     1.571429
# SRH                   -8.700000
# CSK                   -9.500000
# KXIP                 -13.625000
# RR                   -20.200000
# RCB                  -29.800000
# DC                   -35.166667
# KKR                  -36.500000

# %%
plt.figure(figsize=(8,6))
plt.title("Difference between Runs Conceded in 1st innings and Runs Scored in 2nd innings")
sns.barplot(y=diff_conceded_scored.sort_index()['Runs_conceded-Runs_scored'],x=diff_conceded_scored.sort_index().index,palette=colors)
plt.xlabel('Team')
plt.show()

# %% [markdown]
# On an average, Mumbai Indians is the only team that has managed to score atleast one run more than the run they conceded in the first innings

# %%
tot_runs_scored = bat_first_df.sort_index()['Total runs scored'] + bat_second_df.sort_index()['Total runs scored']
tot_wkt_fall = bat_first_df.sort_index()['Total Wicket Fall'] + bat_second_df.sort_index()['Total Wicket Fall']
tot_runs_conceded = field_first_df.sort_index()['Total runs conceded'] + field_second_df.sort_index()['Total runs conceded']
tot_wkts_taken = field_first_df.sort_index()['Total wickets taken'] + field_second_df.sort_index()['Total wickets taken']

# %%
team_summary_df = pd.DataFrame({"Total Runs Scored":tot_runs_scored,'Total Wicket Fall':tot_wkt_fall,
             "Total Runs Conceded":tot_runs_conceded,"Total Wickets Taken":tot_wkts_taken})
team_summary_df.index.name= 'Team'

# %%
team_summary_df
# Out:
#       Total Runs Scored  Total Wicket Fall  Total Runs Conceded  \
# Team
# CSK                2191                 67                 2275
# DC                 2777                105                 2800
# KKR                2219                 96                 2206
# KXIP               2335                 72                 2343
# MI                 2735                 74                 2486
# RCB                2278                 79                 2315
# RR                 2288                 90                 2482
# SRH                2529                 85                 2445
#
#       Total Wickets Taken
# Team
# CSK                    75
# DC                    102
# KKR                    68
# KXIP                   80
# MI                     98
# RCB                    81
# RR                     65
# SRH                    99

# %%
plt.figure(figsize=(8,6))
plt.title("Total Runs Scored By Each Team")
sns.barplot(y=team_summary_df.sort_index()['Total Runs Scored'],x=team_summary_df.sort_index().index,palette=colors)
plt.xlabel('Team')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title("Total Runs Conceded By Each Team")
sns.barplot(y=team_summary_df.sort_index()['Total Runs Conceded'],x=team_summary_df.sort_index().index,palette=colors)
plt.xlabel('Team')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title("Total Wicket Fall Of Each Team")
sns.barplot(y=team_summary_df.sort_index()['Total Wicket Fall'],x=team_summary_df.sort_index().index,palette=colors)
plt.xlabel('Team')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title("Total Wickets Taken by By Each Team")
sns.barplot(y=team_summary_df.sort_index()['Total Wickets Taken'],x=team_summary_df.sort_index().index,palette=colors)
plt.xlabel('Team')
plt.show()
